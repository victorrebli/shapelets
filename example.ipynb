# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pylab as plt
import run as run
# Out:
# [05/25 03:14:49] Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
data = pd.read_csv('data/creditcard.csv')

# %%
data_0 = data[data.Class == 0].sample(frac=0.001).reset_index(drop=True)
data_1 = data[data.Class == 1].sample(frac=0.1).reset_index(drop=True)

# %%
data_all = pd.concat([data_0, data_1])

# %%
label = data_all.Class
data_all = data_all.drop(['Time', 'Class',], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(data_all, label, test_size=0.90, random_state=42)

# %%
pd.value_counts(y_train)
# Out:
# 0    29
# 1     4
# Name: Class, dtype: int64

# %%
data_list = []
for i in range(0,X_train.shape[0]):
      
      data_list.append((X_train.iloc[i].values,y_train.iloc[i]))

# %%
shap, dist = shapelet_dict5 = run.find_shapelets_bf(data_list, max_len=20, min_len=20)
# Out:
# [05/25 03:14:51] Generating the condidates...
# [05/25 03:14:51] Total Candidates: 330
# [05/25 03:14:53] 0 / 330: Gain: 0.5328350630342235 Dist: 24.0
# [05/25 03:14:53] Found new best shapelet with gain & dist: 0.5328350630342235/24.0
# [05/25 03:14:55] 1 / 330: Gain: 0.5328350630342235 Dist: 24.0
# [05/25 03:14:56] 2 / 330: Gain: 0.5328350630342235 Dist: 23.0
# [05/25 03:14:57] 3 / 330: Gain: 0.5328350630342235 Dist: 22.0
# [05/25 03:14:59] 4 / 330: Gain: 0.5328350630342235 Dist: 21.0
# [05/25 03:15:00] 5 / 330: Gain: 0.5328350630342235 Dist: 21.0
# [05/25 03:15:02] 6 / 330: Gain: 0.5328350630342235 Dist: 22.0
# [05/25 03:15:03] 7 / 330: Gain: 0.5328350630342235 Dist: 21.0
# [05/25 03:15:05] 8 / 330: Gain: 0.5328350630342235 Dist: 20.0
# [05/25 03:15:06] 9 / 330: Gain: 0.5328350630342235 Dist: 35.0
# [05/25 03:15:08] 10 / 330: Gain: 0.5328350630342235 Dist: 25.0
# [05/25 03:15:09] 11 / 330: Gain: 0.5328350630342235 Dist: 24.0
# ...

# %%
preds = []
QTD = 10
for i in np.arange(0, QTD):
    
    plt.plot(list(range(len(X_test.iloc[i]))), X_test.iloc[i])
    _dist, _idx = run.subsequence_dist(X_test.iloc[i], shap)
    plt.plot(list(range(_idx, _idx+len(shap))), shap, color='r')
    plt.show()
# Out:
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('C:\\Users\\reblivi\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000.
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# [05/25 03:23:32] update_title_pos
# ...
